# %%
import os
import re
import json
import nltk
import sys

# %%
os.environ['KMP_DUPLICATE_LIB_OK']='True'

# %%
import spacy

# %%
def load_book(book_path):
    """
    Function to load a book from a text file
    :param book_path: Path to the book text file
    :return: The book text as a string 
    """
    
    with open(book_path, 'r', encoding='utf-8') as book_file:
        book_text = book_file.read()
    return book_text

# %%
CHAPTERS = ["Chapter", "CHAPTER", "ACT"]

def split_book_by_chapter(cleaned_text, spacy_model):
    """
    Split the book into chapters
    :param cleaned_text: the text of the book with the headers and footers removed
    :return: a list of chapters
    """
    for title in CHAPTERS:
        cleaned_text = cleaned_text.replace(title, "Chapter")
    chapters = re.split(r'\bChapter\b', cleaned_text)
    add_chapter = []

    for c in chapters:
        new_chapter = "Chapter " + c[1:]
        add_chapter.append(new_chapter)
    
    chapters = [spacy_model(chapter) for chapter in add_chapter]

    return chapters

# %%
def perform_ner(chapters):
    """
    Function to perform named entity recognition on a text
    :param text: The text to perform NER on
    :param spacy_model: The spaCy model to use for NER
    :return: A list of named entities
    """
    
    entities = []
    for chapter in chapters:
        for ent in chapter.ents:
            if ent.label_ == "PERSON":
                entities.append(ent.text)

    return entities

# %%
def count_entities(entities:list)->list:
    """
    Counts the number of times each entity appears in the text
    :param text: 
    :param words: list of words to count
    :return: dictionary with words as keys and number of times they appear in the text as values
    """
    set_entities = set(entities)
    entities_tuples = {}

    for word in set_entities:
        count = entities.count(word)
        if count > 5:
            entities_tuples[word] = count

    return entities_tuples

# %%
def extract_chapter_numbers(text):
    match = re.search(r'\b([IVXLCDM]+|\d+(\.\d+)?)\.', text)
    if match:
        return match.group(1)
    return None

# %%
def extract_character_lines_with_chapters(chapters, characters):
    current_chapter = None
    character_lines = {}

    for chapter in chapters:
        for line in chapter.sents:
            line = line.text.strip()
            if line.startswith("Chapter "):
                current_chapter = extract_chapter_numbers(line)
                continue

            for character in characters:
                if character in line:
                    # Check if the character already has an entry for the current sentence
                    existing_entry = next((entry for entry in character_lines.get(character, []) if entry[1] == line), None)

                    if existing_entry is None:
                        if character not in character_lines:
                            character_lines[character] = []
                        character_lines[character].append((current_chapter, line.replace("\n", "")))
    return character_lines

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import math

def extract_features(character_sentences: dict) -> list:
    """
    Calculates the TF-IDF score for each entity
    :param character_sentences: dictionary containing character sentences
    :return: list of TF-IDF vectors
    """
    # Tokenize and preprocess the sentences
    stop_words = set(stopwords.words('english'))

    def preprocess_sentence(sentence):
        tokens = re.sub(r'[^\w\s]', '', sentence)
        tokens = word_tokenize(tokens.lower())
        tokens = [word for word in tokens if word.isalpha()]
        tokens = [word for word in tokens if word not in stop_words]
        return tokens

    document_frequency = {}
    total_documents = len(character_sentences)

    # Count document frequency for each term
    for _, sentences in character_sentences.items():
        term_set = set()
        for _, sent in sentences:
            terms = preprocess_sentence(sent)
            term_set.update(terms)
        for term in term_set:
            document_frequency[term] = document_frequency.get(term, 0) + 1

    # Calculate TF-IDF score for each term
    tfidf_vectors = []
    term_list = list(document_frequency.keys())

    for _, sentences in character_sentences.items():
        term_frequency = {}
        terms_in_character = 0

        for _, sentence in sentences:
            terms = preprocess_sentence(sentence)
            terms_in_character += len(terms)

            for term in terms:
                term_frequency[term] = term_frequency.get(term, 0) + 1

        tfidf_vector = [term_frequency.get(term, 0) / terms_in_character * math.log(total_documents / (1 + document_frequency[term]))
                        for term in term_list]
        tfidf_vectors.append(tfidf_vector)

    return tfidf_vectors, term_list


def clustering_aliases(entities:list, character_sentences:dict):
    # Perform the TF-IDF feature extraction
    features, term_list = extract_features(character_sentences)

    # Create a KMeansClusterer object with the number of clusters, cosine distance, and 10 repeats
    n_clusters = len(set(entities))
    kclusterer = nltk.cluster.KMeansClusterer(n_clusters, distance=nltk.cluster.util.cosine_distance, repeats=10)

    # Cluster the feature vectors and assign a cluster label to each entity
    clusters = kclusterer.cluster(features, assign_clusters=True)

    # Create a dictionary entities as keys and all their aliases as values
    cluster_dict = {character: [] for character in entities}

    # Create a dictionary with the cluster label as key and the entities in the cluster as values
    cluster_dict = {}
    for i, cluster in enumerate(clusters):
        if cluster not in cluster_dict:
            cluster_dict[cluster] = []
        cluster_dict[cluster].append(entities[i])

    # Convert the dictionary values to lists when keys are equal
    result_dict = {}
    for key, value in cluster_dict.items():
        if len(value) > 1:
            result_dict[key] = value
        else:
            result_dict[key] = value[0]

    return result_dict

# %%
nlp = spacy.load("en_core_web_lg")

# %%
import json

def find_start_end_indices(substring, full_text):
    start_index = full_text.find(substring)
    end_index = start_index + len(substring)
    return start_index, end_index

def create_json_structure(characters_frequency, characters_aliases, characters_occurrences):
    get_aliases ={}
    for name in characters_occurrences.keys():
        for _, value in characters_aliases.items():
            if name in value:
                get_aliases[name] = value

    json_structure = {"main_characters": []}

    for character in characters_frequency:
        aliases = get_aliases.get(character, [])
        occurrences = characters_occurrences.get(character, [])
        frequency = characters_frequency.get(character, 0)       

        character_data = {
            "name": character,
            "aliases": aliases,
            "frequency": frequency,
            "occurrences": []
        }

        for chapter, context in occurrences:
            # Assuming you have start and end indices available
            start_index, end_index = find_start_end_indices(character, context)

            occurrence_data = {
                "sentence": context,
                "chapter": chapter,
                "position": {"start": start_index, "end": end_index}
            }

            character_data["occurrences"].append(occurrence_data)

        json_structure["main_characters"].append(character_data)

    return json_structure

# %%
def write_as_json(book_path, resulting_json, directory_path):
    """
    Write the data to a JSON file.
    """
    # Get the book title from the file path
    book_title = os.path.basename(book_path).replace("_clean.txt", "")
    result = json.dumps(resulting_json, ensure_ascii=False, indent=2)

    # Create the output file path
    file_name = f"{book_title}_MainCharacters_NER.json"
    output_file_path = os.path.join(directory_path, file_name)

    with open(output_file_path, "w", encoding="utf-8") as json_file:
        json_file.write(result)

# %%
book_path = "/Users/dariastetsenko/Desktop/pcl1/Programming-for-Linguists-Project/Alice_in_wonderland/Alice_in_wonderland_clean.txt"

book_text = load_book(book_path)
chapters = [chapter for chapter in split_book_by_chapter(book_text, nlp) if len(chapter) > 1000]
# book_cleaned = "".join(chapters)

# Characters in the book
extract_entities = perform_ner(chapters)
# # # Characters frequency in the book
characters_frequency = count_entities(extract_entities)
# # # Get the most frequent characters
# main_characters_frequencies = sorted(characters_frequency.items(), key=lambda x: x[1], reverse=True)[:5]
main_characters = list(characters_frequency.keys())

# # # # Characters with their lines and chapters
characters_occurrences = extract_character_lines_with_chapters(chapters, main_characters)
# # # Characters with their aliases
characters_aliases = clustering_aliases(main_characters, characters_occurrences)

resulting_json = create_json_structure(characters_frequency, characters_aliases, characters_occurrences)

# %%
resulting_json
# Out:
# {'main_characters': [{'name': 'Hatter',
#    'aliases': 'Hatter',
#    'frequency': 55,
#    'occurrences': [{'sentence': '“What sort of people live about here?”“In _that_ direction,” the Cat said, waving its right paw round, “livesa Hatter: and in _that_ direction,” waving the other paw, “lives aMarch Hare.',
#      'chapter': 'VI',
#      'position': {'start': 111, 'end': 117}},
#     {'sentence': 'I almost wish I’d gone to see the Hatter instead!”',
#      'chapter': 'VI',
#      'position': {'start': 34, 'end': 40}},
#     {'sentence': 'A Mad Tea-PartyThere was a table set out under a tree in front of the house, and theMarch Hare and the Hatter were having tea at it: a Dormouse was sittingbetween them, fast asleep, and the other two were using it as acushion, resting their elbows on it, and talking over its head.',
#      'chapter': 'VII',
#      'position': {'start': 103, 'end': 109}},
#     {'sentence': '“Your hair wants cutting,” said the Hatter.',
#      'chapter': 'VII',
#      'position': {'start': 36, 'end': 42}},
#     {'sentence': 'The Hatter opened his eyes very wide on hearing this; but all he _said_was, “Why is a raven like a writing-desk?”“Come, we shall have some fun now!” thought Alice.',
#      'chapter': 'VII',
#      'position': {'start': 4, 'end': 10}},
#     {'sentence': '“I do,” Alice hastily replied; “at least—at least I mean what Isay—that’s the same thing, you know.”“Not the same thing a bit!” said the Hatter.',
#      'chapter': 'VII',
#      'position': {'start': 137, 'end': 143}},
#     {'sentence': '“It _is_ the same thing with you,” said the Hatter, and here theconversation dropped, and the party sat silent for a minute, whileAlice thought over all she could remember about ravens andwriting-desks, which wasn’t much.',
#      'chapter': 'VII',
#      'position': {'start': 44, 'end': 50}},
#     {'sentence': 'The Hatter was the first to break the silence.',
#      'chapter': 'VII',
#      'position': {'start': 4, 'end': 10}},
#     {'sentence': '“Two days wrong!” sighed the Hatter.',
#      'chapter': 'VII',
#      'position': {'start': 29, 'end': 35}},
#     {'sentence': '“Yes, but some crumbs must have got in as well,” the Hatter grumbled:“you shouldn’t have put it in with the bread-knife.”',
#      'chapter': 'VII',
#      'position': {'start': 53, 'end': 59}},
#     {'sentence': '“Why should it?” muttered the Hatter.',
#      'chapter': 'VII',
#      'position': {'start': 30, 'end': 36}},
#     {'sentence': '“Which is just the case with _mine_,” said the Hatter.',
#      'chapter': 'VII',
#      'position': {'start': 47, 'end': 53}},
#     {'sentence': 'The Hatter’s remark seemed to have nosort of meaning in it, and yet it was certainly English.',
#      'chapter': 'VII',
#      'position': {'start': 4, 'end': 10}},
#     {'sentence': '“The Dormouse is asleep again,” said the Hatter, and he poured a littlehot tea upon its nose.',
#      'chapter': 'VII',
#      'position': {'start': 41, 'end': 47}},
#     {'sentence': 'the Hatter said, turning to Aliceagain.',
#      'chapter': 'VII',
#      'position': {'start': 4, 'end': 10}},
#     {'sentence': '“No, I give it up,” Alice replied: “what’s the answer?”“I haven’t the slightest idea,” said the Hatter.',
#      'chapter': 'VII',
#      'position': {'start': 96, 'end': 102}},
#     {'sentence': '“I think you might do something better with thetime,” she said, “than waste it in asking riddles that have noanswers.”“If you knew Time as well as I do,” said the Hatter, “you wouldn’t talkabout wasting _it_.',
#      'chapter': 'VII',
#      'position': {'start': 163, 'end': 169}},
#     {'sentence': 'the Hatter said, tossing his headcontemptuously.',
#      'chapter': 'VII',
#      'position': {'start': 4, 'end': 10}},
#     {'sentence': '“Perhaps not,” Alice cautiously replied: “but I know I have to beattime when I learn music.”“Ah! that accounts for it,” said the Hatter.',
#      'chapter': 'VII',
#      'position': {'start': 129, 'end': 135}},
#     {'sentence': '“Not at first, perhaps,” said the Hatter: “but you could keep it tohalf-past one as long as you liked.”“Is that the way _you_ manage?”',
#      'chapter': 'VII',
#      'position': {'start': 34, 'end': 40}},
#     {'sentence': 'The Hatter shook his head mournfully.',
#      'chapter': 'VII',
#      'position': {'start': 4, 'end': 10}},
#     {'sentence': '“It goes on, you know,” the Hatter continued, “in this way:—‘Up above the world you fly,Like a tea-tray in the sky.',
#      'chapter': 'VII',
#      'position': {'start': 28, 'end': 34}},
#     {'sentence': '“Well, I’d hardly finished the first verse,” said the Hatter, “when theQueen jumped up and bawled out, ‘He’s murdering the time!',
#      'chapter': 'VII',
#      'position': {'start': 54, 'end': 60}},
#     {'sentence': '“And ever since that,” the Hatter went on in a mournful tone, “he won’tdo a thing I ask!',
#      'chapter': 'VII',
#      'position': {'start': 27, 'end': 33}},
#     {'sentence': '“Yes, that’s it,” said the Hatter with a sigh: “it’s always tea-time,and we’ve no time to wash the things between whiles.”',
#      'chapter': 'VII',
#      'position': {'start': 27, 'end': 33}},
#     {'sentence': '“Exactly so,” said the Hatter: “as the things get used up.”',
#      'chapter': 'VII',
#      'position': {'start': 23, 'end': 29}},
#     {'sentence': '“And be quick about it,” added the Hatter, “or you’ll be asleep againbefore it’s done.”“Once upon a time there were three little sisters,” the Dormouse beganin a great hurry; “and their names were Elsie, Lacie, and Tillie; andthey lived at the bottom of a well—”“What did they live on?” said Alice, who always took a great interestin questions of eating and drinking.',
#      'chapter': 'VII',
#      'position': {'start': 35, 'end': 41}},
#     {'sentence': '“I’ve had nothing yet,” Alice replied in an offended tone, “so I can’ttake more.”“You mean you can’t take _less_,” said the Hatter: “it’s very easy totake _more_ than nothing.”',
#      'chapter': 'VII',
#      'position': {'start': 124, 'end': 130}},
#     {'sentence': 'the Hatter asked triumphantly.',
#      'chapter': 'VII',
#      'position': {'start': 4, 'end': 10}},
#     {'sentence': 'Alice was beginning very angrily, but theHatter and the March Hare went “Sh! sh!” and the Dormouse sulkilyremarked, “If you can’t be civil, you’d better finish the story foryourself.”“No, please go on!”',
#      'chapter': 'VII',
#      'position': {'start': 41, 'end': 47}},
#     {'sentence': '“I want a clean cup,” interrupted the Hatter: “let’s all move one placeon.”He moved on as he spoke, and the Dormouse followed him: the March Haremoved into the Dormouse’s place, and Alice rather unwillingly took theplace of the March Hare.',
#      'chapter': 'VII',
#      'position': {'start': 38, 'end': 44}},
#     {'sentence': 'The Hatter was the only one who got anyadvantage from the change: and Alice was a good deal worse off thanbefore, as the March Hare had just upset the milk-jug into his plate.',
#      'chapter': 'VII',
#      'position': {'start': 4, 'end': 10}},
#     {'sentence': 'Where did they draw the treaclefrom?”“You can draw water out of a water-well,” said the Hatter; “so I shouldthink you could draw treacle out of a treacle-well—eh, stupid?”“But they were _in_ the well,” Alice said to the Dormouse, not choosingto notice this last remark.',
#      'chapter': 'VII',
#      'position': {'start': 88, 'end': 94}},
#     {'sentence': 'The Dormouse had closed its eyes by this time, and was going off into adoze; but, on being pinched by the Hatter, it woke up again with alittle shriek, and went on: “—that begins with an M, such asmouse-traps, and the moon, and memory, and muchness—you know you saythings are “much of a muchness”—did you ever see such a thing as adrawing of a muchness?”“Really, now you ask me,” said Alice, very much confused, “I don’tthink—”“Then you shouldn’t talk,” said the Hatter.',
#      'chapter': 'VII',
#      'position': {'start': 106, 'end': 112}},
#     {'sentence': 'The first witness was the Hatter.',
#      'chapter': 'XI',
#      'position': {'start': 26, 'end': 32}},
#     {'sentence': '“When did you begin?”The Hatter looked at the March Hare, who had followed him into thecourt, arm-in-arm with the Dormouse.',
#      'chapter': 'XI',
#      'position': {'start': 25, 'end': 31}},
#     {'sentence': '“Take off your hat,” the King said to the Hatter.',
#      'chapter': 'XI',
#      'position': {'start': 42, 'end': 48}},
#     {'sentence': '“It isn’t mine,” said the Hatter.',
#      'chapter': 'XI',
#      'position': {'start': 26, 'end': 32}},
#     {'sentence': '“I keep them to sell,” the Hatter added as an explanation; “I’ve noneof my own.',
#      'chapter': 'XI',
#      'position': {'start': 27, 'end': 33}},
#     {'sentence': 'Here the Queen put on her spectacles, and began staring at the Hatter,who turned pale and fidgeted.',
#      'chapter': 'XI',
#      'position': {'start': 63, 'end': 69}},
#     {'sentence': 'All this time the Queen had never left off staring at the Hatter, and,just as the Dormouse crossed the court, she said to one of the officersof the court, “Bring me the list of the singers in the last concert!”on which the wretched Hatter trembled so, that he shook both his shoesoff.',
#      'chapter': 'XI',
#      'position': {'start': 58, 'end': 64}},
#     {'sentence': '“I’m a poor man, your Majesty,” the Hatter began, in a trembling voice,“—and I hadn’t begun my tea—not above a week or so—and what with thebread-and-butter getting so thin—and the twinkling of the tea—”“The twinkling of the _what?_” said the King.',
#      'chapter': 'XI',
#      'position': {'start': 36, 'end': 42}},
#     {'sentence': '“It _began_ with the tea,” the Hatter replied.',
#      'chapter': 'XI',
#      'position': {'start': 31, 'end': 37}},
#     {'sentence': 'Go on!”“I’m a poor man,” the Hatter went on, “and most things twinkled afterthat—only the March Hare said—”“I didn’t!”',
#      'chapter': 'XI',
#      'position': {'start': 29, 'end': 35}},
#     {'sentence': '“You did!” said the Hatter.',
#      'chapter': 'XI',
#      'position': {'start': 20, 'end': 26}},
#     {'sentence': '“He denies it,” said the King: “leave out that part.”“Well, at any rate, the Dormouse said—” the Hatter went on, lookinganxiously round to see if he would deny it too: but the Dormouse deniednothing, being fast asleep.',
#      'chapter': 'XI',
#      'position': {'start': 97, 'end': 103}},
#     {'sentence': '“After that,” continued the Hatter, “I cut some more bread-and-butter—”“But what did the Dormouse say?”',
#      'chapter': 'XI',
#      'position': {'start': 28, 'end': 34}},
#     {'sentence': '“That I can’t remember,” said the Hatter.',
#      'chapter': 'XI',
#      'position': {'start': 34, 'end': 40}},
#     {'sentence': 'The miserable Hatter dropped his teacup and bread-and-butter, and wentdown on one knee.',
#      'chapter': 'XI',
#      'position': {'start': 14, 'end': 20}},
#     {'sentence': '“I can’t go no lower,” said the Hatter: “I’m on the floor, as it is.”',
#      'chapter': 'XI',
#      'position': {'start': 32, 'end': 38}},
#     {'sentence': '“I’d rather finish my tea,” said the Hatter, with an anxious look atthe Queen, who was reading the list of singers.',
#      'chapter': 'XI',
#      'position': {'start': 37, 'end': 43}},
#     {'sentence': '“You may go,” said the King, and the Hatter hurriedly left the court,without even waiting to put his shoes on.',
#      'chapter': 'XI',
#      'position': {'start': 37, 'end': 43}},
#     {'sentence': '“—and just take his head off outside,” the Queen added to one of theofficers: but the Hatter was out of sight before the officer could getto the door.',
#      'chapter': 'XI',
#      'position': {'start': 86, 'end': 92}}]},
#   {'name': 'Dormouse',
#    'aliases': 'Dormouse',
#    'frequency': 17,
#    'occurrences': [{'sentence': 'A Mad Tea-PartyThere was a table set out under a tree in front of the house, and theMarch Hare and the Hatter were having tea at it: a Dormouse was sittingbetween them, fast asleep, and the other two were using it as acushion, resting their elbows on it, and talking over its head.',
#      'chapter': 'VII',
#      'position': {'start': 135, 'end': 143}},
#     {'sentence': '“Veryuncomfortable for the Dormouse,” thought Alice; “only, as it’s asleep,I suppose it doesn’t mind.”',
#      'chapter': 'VII',
#      'position': {'start': 27, 'end': 35}},
#     {'sentence': '“You might just as wellsay that ‘I see what I eat’ is the same thing as ‘I eat what I see’!”“You might just as well say,” added the March Hare, “that ‘I like whatI get’ is the same thing as ‘I get what I like’!”“You might just as well say,” added the Dormouse, who seemed to betalking in his sleep, “that ‘I breathe when I sleep’ is the same thingas ‘I sleep when I breathe’!”',
#      'chapter': 'VII',
#      'position': {'start': 251, 'end': 259}},
#     {'sentence': '“The Dormouse is asleep again,” said the Hatter, and he poured a littlehot tea upon its nose.',
#      'chapter': 'VII',
#      'position': {'start': 5, 'end': 13}},
#     {'sentence': 'The Dormouse shook its head impatiently, and said, without opening itseyes, “Of course, of course; just what I was going to remark myself.”“Have you guessed the riddle yet?”',
#      'chapter': 'VII',
#      'position': {'start': 4, 'end': 12}},
#     {'sentence': 'Twinkle, twinkle—’”Here the Dormouse shook itself, and began singing in its sleep“_Twinkle, twinkle, twinkle, twinkle_—” and went on so long that theyhad to pinch it to make it stop.',
#      'chapter': 'VII',
#      'position': {'start': 28, 'end': 36}},
#     {'sentence': '“Then the Dormouse shall!”',
#      'chapter': 'VII',
#      'position': {'start': 10, 'end': 18}},
#     {'sentence': '“Wake up, Dormouse!”',
#      'chapter': 'VII',
#      'position': {'start': 10, 'end': 18}},
#     {'sentence': 'The Dormouse slowly opened his eyes.',
#      'chapter': 'VII',
#      'position': {'start': 4, 'end': 12}},
#     {'sentence': '“And be quick about it,” added the Hatter, “or you’ll be asleep againbefore it’s done.”“Once upon a time there were three little sisters,” the Dormouse beganin a great hurry; “and their names were Elsie, Lacie, and Tillie; andthey lived at the bottom of a well—”“What did they live on?” said Alice, who always took a great interestin questions of eating and drinking.',
#      'chapter': 'VII',
#      'position': {'start': 143, 'end': 151}},
#     {'sentence': '“They lived on treacle,” said the Dormouse, after thinking a minute ortwo.',
#      'chapter': 'VII',
#      'position': {'start': 34, 'end': 42}},
#     {'sentence': '“They couldn’t have done that, you know,” Alice gently remarked;“they’d have been ill.”“So they were,” said the Dormouse; “_very_ ill.”Alice tried to fancy to herself what such an extraordinary ways ofliving would be like, but it puzzled her too much, so she went on: “Butwhy did they live at the bottom of a well?”“Take some more tea,” the March Hare said to Alice, very earnestly.',
#      'chapter': 'VII',
#      'position': {'start': 112, 'end': 120}},
#     {'sentence': 'Alice did not quite know what to say to this: so she helped herself tosome tea and bread-and-butter, and then turned to the Dormouse, andrepeated her question.',
#      'chapter': 'VII',
#      'position': {'start': 124, 'end': 132}},
#     {'sentence': '“Why did they live at the bottom of a well?”The Dormouse again took a minute or two to think about it, and thensaid, “It was a treacle-well.”“There’s no such thing!”',
#      'chapter': 'VII',
#      'position': {'start': 48, 'end': 56}},
#     {'sentence': 'Alice was beginning very angrily, but theHatter and the March Hare went “Sh! sh!” and the Dormouse sulkilyremarked, “If you can’t be civil, you’d better finish the story foryourself.”“No, please go on!”',
#      'chapter': 'VII',
#      'position': {'start': 90, 'end': 98}},
#     {'sentence': '“One, indeed!” said the Dormouse indignantly.',
#      'chapter': 'VII',
#      'position': {'start': 24, 'end': 32}},
#     {'sentence': '“Treacle,” said the Dormouse, without considering at all this time.',
#      'chapter': 'VII',
#      'position': {'start': 20, 'end': 28}},
#     {'sentence': '“I want a clean cup,” interrupted the Hatter: “let’s all move one placeon.”He moved on as he spoke, and the Dormouse followed him: the March Haremoved into the Dormouse’s place, and Alice rather unwillingly took theplace of the March Hare.',
#      'chapter': 'VII',
#      'position': {'start': 108, 'end': 116}},
#     {'sentence': 'Alice did not wish to offend the Dormouse again, so she began verycautiously: “But I don’t understand.',
#      'chapter': 'VII',
#      'position': {'start': 33, 'end': 41}},
#     {'sentence': 'Where did they draw the treaclefrom?”“You can draw water out of a water-well,” said the Hatter; “so I shouldthink you could draw treacle out of a treacle-well—eh, stupid?”“But they were _in_ the well,” Alice said to the Dormouse, not choosingto notice this last remark.',
#      'chapter': 'VII',
#      'position': {'start': 220, 'end': 228}},
#     {'sentence': '“Of course they were,” said the Dormouse; “—well in.”',
#      'chapter': 'VII',
#      'position': {'start': 32, 'end': 40}},
#     {'sentence': 'This answer so confused poor Alice, that she let the Dormouse go on forsome time without interrupting it.',
#      'chapter': 'VII',
#      'position': {'start': 53, 'end': 61}},
#     {'sentence': '“They were learning to draw,” the Dormouse went on, yawning and rubbingits eyes, for it was getting very sleepy; “and they drew all manner ofthings—everything that begins with an M—”“Why with an M?” said Alice.',
#      'chapter': 'VII',
#      'position': {'start': 34, 'end': 42}},
#     {'sentence': 'The Dormouse had closed its eyes by this time, and was going off into adoze; but, on being pinched by the Hatter, it woke up again with alittle shriek, and went on: “—that begins with an M, such asmouse-traps, and the moon, and memory, and muchness—you know you saythings are “much of a muchness”—did you ever see such a thing as adrawing of a muchness?”“Really, now you ask me,” said Alice, very much confused, “I don’tthink—”“Then you shouldn’t talk,” said the Hatter.',
#      'chapter': 'VII',
#      'position': {'start': 4, 'end': 12}},
#     {'sentence': 'This piece of rudeness was more than Alice could bear: she got up ingreat disgust, and walked off; the Dormouse fell asleep instantly, andneither of the others took the least notice of her going, though shelooked back once or twice, half hoping that they would call after her:the last time she saw them, they were trying to put the Dormouse intothe teapot.',
#      'chapter': 'VII',
#      'position': {'start': 103, 'end': 111}},
#     {'sentence': '“When did you begin?”The Hatter looked at the March Hare, who had followed him into thecourt, arm-in-arm with the Dormouse.',
#      'chapter': 'XI',
#      'position': {'start': 114, 'end': 122}},
#     {'sentence': '“Sixteenth,” added the Dormouse.',
#      'chapter': 'XI',
#      'position': {'start': 23, 'end': 31}},
#     {'sentence': '“I wish you wouldn’t squeeze so.” said the Dormouse, who was sittingnext to her.',
#      'chapter': 'XI',
#      'position': {'start': 43, 'end': 51}},
#     {'sentence': '“You’ve no right to grow _here_,” said the Dormouse.',
#      'chapter': 'XI',
#      'position': {'start': 43, 'end': 51}},
#     {'sentence': '“Don’t talk nonsense,” said Alice more boldly: “you know you’re growingtoo.”“Yes, but _I_ grow at a reasonable pace,” said the Dormouse: “not inthat ridiculous fashion.”',
#      'chapter': 'XI',
#      'position': {'start': 127, 'end': 135}},
#     {'sentence': 'All this time the Queen had never left off staring at the Hatter, and,just as the Dormouse crossed the court, she said to one of the officersof the court, “Bring me the list of the singers in the last concert!”on which the wretched Hatter trembled so, that he shook both his shoesoff.',
#      'chapter': 'XI',
#      'position': {'start': 82, 'end': 90}},
#     {'sentence': '“He denies it,” said the King: “leave out that part.”“Well, at any rate, the Dormouse said—” the Hatter went on, lookinganxiously round to see if he would deny it too: but the Dormouse deniednothing, being fast asleep.',
#      'chapter': 'XI',
#      'position': {'start': 77, 'end': 85}},
#     {'sentence': '“After that,” continued the Hatter, “I cut some more bread-and-butter—”“But what did the Dormouse say?”',
#      'chapter': 'XI',
#      'position': {'start': 89, 'end': 97}},
#     {'sentence': '“Collar that Dormouse,” the Queen shrieked out.',
#      'chapter': 'XI',
#      'position': {'start': 13, 'end': 21}},
#     {'sentence': '“Behead that Dormouse!',
#      'chapter': 'XI',
#      'position': {'start': 13, 'end': 21}},
#     {'sentence': 'Turn that Dormouse out of court!',
#      'chapter': 'XI',
#      'position': {'start': 10, 'end': 18}},
#     {'sentence': 'Off with hiswhiskers!”For some minutes the whole court was in confusion, getting the Dormouseturned out, and, by the time they had settled down again, the cook haddisappeared.',
#      'chapter': 'XI',
#      'position': {'start': 85, 'end': 93}}]},
#   {'name': 'Alice',
#    'aliases': 'Alice',
#    'frequency': 396,
#    'occurrences': [{'sentence': 'There was nothing so _very_ remarkable in that; nor did Alice think itso _very_',
#      'chapter': 'I',
#      'position': {'start': 56, 'end': 61}},
#     {'sentence': '(when she thought it over afterwards,it occurred to her that she ought to have wondered at this, but at thetime it all seemed quite natural); but when the Rabbit actually _took awatch out of its waistcoat-pocket_, and looked at it, and then hurriedon, Alice started to her feet, for it flashed across her mind that shehad never before seen a rabbit with either a waistcoat-pocket, or awatch to take out of it, and burning with curiosity, she ran across thefield after it, and fortunately was just in time to see it pop down alarge rabbit-hole under the hedge.',
#      'chapter': 'I',
#      'position': {'start': 252, 'end': 257}},
#     {'sentence': 'In another moment down went Alice after it, never once considering howin the world she was to get out again.',
#      'chapter': 'I',
#      'position': {'start': 28, 'end': 33}},
#     {'sentence': 'The rabbit-hole went straight on like a tunnel for some way, and thendipped suddenly down, so suddenly that Alice had not a moment to thinkabout stopping herself before she found herself falling down a verydeep well.',
#      'chapter': 'I',
#      'position': {'start': 108, 'end': 113}},
#     {'sentence': '“Well!” thought Alice to herself, “after such a fall as this, I shallthink nothing of tumbling down stairs!',
#      'chapter': 'I',
#      'position': {'start': 16, 'end': 21}},
#     {'sentence': 'Let me see: that wouldbe four thousand miles down, I think—” (for, you see, Alice had learntseveral things of this sort in her lessons in the schoolroom, andthough this was not a _very_ good opportunity for showing off herknowledge, as there was no one to listen to her, still it was goodpractice to say it over)',
#      'chapter': 'I',
#      'position': {'start': 76, 'end': 81}},
#     {'sentence': '(Alice had noidea what Latitude was, or Longitude either, but thought they were nicegrand words to say.)',
#      'chapter': 'I',
#      'position': {'start': 1, 'end': 6}},
#     {'sentence': 'There was nothing else to do, so Alice soon begantalking again.',
#      'chapter': 'I',
#      'position': {'start': 33, 'end': 38}},
#     {'sentence': 'And hereAlice began to get rather sleepy, and went on saying to herself, in adreamy sort of way, “Do cats eat bats?',
#      'chapter': 'I',
#      'position': {'start': 8, 'end': 13}},
#     {'sentence': 'Alice was not a bit hurt, and she jumped up on to her feet in a moment:she looked up, but it was all dark overhead; before her was anotherlong passage, and the White Rabbit was still in sight, hurrying downit.',
#      'chapter': 'I',
#      'position': {'start': 0, 'end': 5}},
#     {'sentence': 'There was not a moment to be lost: away went Alice like the wind,and was just in time to hear it say, as it turned a corner, “Oh my earsand whiskers, how late it’s getting!”',
#      'chapter': 'I',
#      'position': {'start': 45, 'end': 50}},
#     {'sentence': 'There were doors all round the hall, but they were all locked; and whenAlice had been all the way down one side and up the other, trying everydoor, she walked sadly down the middle, wondering how she was ever toget out again.',
#      'chapter': 'I',
#      'position': {'start': 71, 'end': 76}},
#     {'sentence': 'Suddenly she came upon a little three-legged table, all made of solidglass; there was nothing on it except a tiny golden key, and Alice’sfirst thought was that it might belong to one of the doors of the hall;',
#      'chapter': 'I',
#      'position': {'start': 130, 'end': 135}},
#     {'sentence': 'Alice opened the door and found that it led into a small passage, notmuch larger than a rat-hole: she knelt down and looked along thepassage into the loveliest garden you ever saw.',
#      'chapter': 'I',
#      'position': {'start': 0, 'end': 5}},
#     {'sentence': 'How she longed to getout of that dark hall, and wander about among those beds of brightflowers and those cool fountains, but she could not even get her headthrough the doorway; “and even if my head would go through,” thoughtpoor Alice, “it would be of very little use without my shoulders.',
#      'chapter': 'I',
#      'position': {'start': 229, 'end': 234}},
#     {'sentence': 'For, you see, so many out-of-the-way things hadhappened lately, that Alice had begun to think that very few thingsindeed were really impossible.',
#      'chapter': 'I',
#      'position': {'start': 69, 'end': 74}},
#     {'sentence': 'There seemed to be no use in waiting by the little door, so she wentback to the table, half hoping she might find another key on it, or atany rate a book of rules for shutting people up like telescopes: thistime she found a little bottle on it, (“which certainly was not herebefore,” said Alice,) and round the neck of the bottle was a paperlabel, with the words “DRINK ME,” beautifully printed on it in largeletters.',
#      'chapter': 'I',
#      'position': {'start': 289, 'end': 294}},
#     {'sentence': 'It was all very well to say “Drink me,” but the wise little Alice wasnot going to do _that_ in a hurry.',
#      'chapter': 'I',
#      'position': {'start': 60, 'end': 65}},
#     {'sentence': 'However, this bottle was _not_ marked “poison,” so Alice ventured totaste it, and finding it very nice, (it had, in fact, a sort of mixedflavour of cherry-tart, custard, pine-apple, roast turkey, toffee, andhot buttered toast,) she very soon finished it off.',
#      'chapter': 'I',
#      'position': {'start': 51, 'end': 56}},
#     {'sentence': '*      *      *      *      *      *      *    *      *      *      *      *      **      *      *      *      *      *      *“What a curious feeling!” said Alice; “I must be shutting up like atelescope.”',
#      'chapter': 'I',
#      'position': {'start': 157, 'end': 162}},
#     {'sentence': 'First, however, shewaited for a few minutes to see if she was going to shrink any further:she felt a little nervous about this; “for it might end, you know,”said Alice to herself, “in my going out altogether, like a candle.',
#      'chapter': 'I',
#      'position': {'start': 162, 'end': 167}},
#     {'sentence': 'After a while, finding that nothing more happened, she decided on goinginto the garden at once; but, alas for poor Alice!',
#      'chapter': 'I',
#      'position': {'start': 115, 'end': 120}},
#     {'sentence': '“Come, there’s no use in crying like that!” said Alice to herself,rather sharply; “I advise you to leave off this minute!”',
#      'chapter': 'I',
#      'position': {'start': 49, 'end': 54}},
#     {'sentence': '“But it’s no use now,” thought poor Alice, “to pretend to be twopeople!',
#      'chapter': 'I',
#      'position': {'start': 36, 'end': 41}},
#     {'sentence': '“Well, I’ll eat it,” saidAlice, “and if it makes me grow larger, I can reach the key; and if itmakes me grow smaller, I can creep under the door; so either way I’llget into the garden, and I don’t care which happens!”',
#      'chapter': 'I',
#      'position': {'start': 25, 'end': 30}},
#     {'sentence': 'Whichway?”, holding her hand on the top of her head to feel which way it wasgrowing, and she was quite surprised to find that she remained the samesize: to be sure, this generally happens when one eats cake, but Alicehad got so much into the way of expecting nothing but out-of-the-waythings to happen, that it seemed quite dull and stupid for life to goon in the common way.',
#      'chapter': 'I',
#      'position': {'start': 212, 'end': 217}},
#     {'sentence': 'The Pool of Tears“Curiouser and curiouser!” cried Alice (she was so much surprised, thatfor the moment she quite forgot how to speak good English); “now I’mopening out like the largest telescope that ever was!',
#      'chapter': 'II',
#      'position': {'start': 50, 'end': 55}},
#     {'sentence': 'I shall be a great deal too far off to troublemyself about you: you must manage the best way you can;—but I must bekind to them,” thought Alice, “or perhaps they won’t walk the way Iwant to go!',
#      'chapter': 'II',
#      'position': {'start': 138, 'end': 143}},
#     {'sentence': 'Alice’s Right Foot, Esq., Hearthrug, near the Fender,_ (_with     Alice’s love_).',
#      'chapter': 'II',
#      'position': {'start': 0, 'end': 5}},
#     {'sentence': 'Poor Alice!',
#      'chapter': 'II',
#      'position': {'start': 5, 'end': 10}},
#     {'sentence': '“You ought to be ashamed of yourself,” said Alice, “a great girl likeyou,” (she might well say this), “to go on crying in this way!',
#      'chapter': 'II',
#      'position': {'start': 44, 'end': 49}},
#     {'sentence': 'Alice feltso desperate that she was ready to ask help of any one; so, when theRabbit came near her, she began, in a low, timid voice, “If you please,sir—” The Rabbit started violently, dropped the white kid gloves andthe fan, and skurried away into the darkness as hard as he could go.',
#      'chapter': 'II',
#      'position': {'start': 0, 'end': 5}},
#     {'sentence': 'Alice took up the fan and gloves, and, as the hall was very hot, shekept fanning herself all the time she went on talking: “Dear, dear!',
#      'chapter': 'II',
#      'position': {'start': 0, 'end': 5}},
#     {'sentence': '“How cheerfully he seems to grin,    How neatly spread his claws,And welcome little fishes in    With gently smiling jaws!”“I’m sure those are not the right words,” said poor Alice, and her eyesfilled with tears again as she went on, “I must be Mabel after all, andI shall have to go and live in that poky little house, and have next tono toys to play with, and',
#      'chapter': 'II',
#      'position': {'start': 175, 'end': 180}},
#     {'sentence': 'else’—but, oh dear!” cried Alice, with a suddenburst of tears, “I do wish they _',
#      'chapter': 'II',
#      'position': {'start': 27, 'end': 32}},
#     {'sentence': '“That _was_ a narrow escape!” said Alice, a good deal frightened at thesudden change, but very glad to find herself still in existence; “andnow for the garden!”',
#      'chapter': 'II',
#      'position': {'start': 35, 'end': 40}},
#     {'sentence': '(Alice had been to the seaside once inher life, and had come to the general conclusion, that wherever you goto on the English coast you find a number of bathing machines in thesea, some children digging in the sand with wooden spades, then a rowof lodging houses, and behind them a railway station.)',
#      'chapter': 'II',
#      'position': {'start': 1, 'end': 6}},
#     {'sentence': '“I wish I hadn’t cried so much!” said Alice, as she swam about, tryingto find her way out.',
#      'chapter': 'II',
#      'position': {'start': 38, 'end': 43}},
#     {'sentence': '“Would it be of any use, now,” thought Alice, “to speak to this mouse?',
#      'chapter': 'II',
#      'position': {'start': 39, 'end': 44}},
#     {'sentence': '(Alice thought this must be the rightway of speaking to a mouse: she had never done such a thing before, butshe remembered having seen in her brother’s Latin Grammar, “A mouse—ofa mouse—to a mouse—a mouse—O mouse!”)',
#      'chapter': 'II',
#      'position': {'start': 1, 'end': 6}},
#     {'sentence': '“Perhaps it doesn’t understand English,” thought Alice; “I daresay it’sa French mouse, come over with William the Conqueror.”',
#      'chapter': 'II',
#      'position': {'start': 49, 'end': 54}},
#     {'sentence': '(For, with allher knowledge of history, Alice had no very clear notion how long agoanything had happened.)',
#      'chapter': 'II',
#      'position': {'start': 40, 'end': 45}},
#     {'sentence': '“Oh, I beg your pardon!” cried Alice hastily, afraid that shehad hurt the poor animal’s feelings.',
#      'chapter': 'II',
#      'position': {'start': 31, 'end': 36}},
#     {'sentence': '“Would_you_ like cats if you were me?”“Well, perhaps not,” said Alice in a soothing tone: “don’t be angryabout it.',
#      'chapter': 'II',
#      'position': {'start': 64, 'end': 69}},
#     {'sentence': 'She is such a dearquiet thing,” Alice went on, half to herself, as she swam lazily aboutin the pool, “and she sits purring so nicely by the fire, licking herpaws and washing her face—and she is such a nice soft thing tonurse—and she’s such a capital one for catching mice—oh, I beg yourpardon!” cried Alice again, for this time the Mouse was bristling allover, and she felt certain it must be really offended.',
#      'chapter': 'II',
#      'position': {'start': 32, 'end': 37}},
#     {'sentence': 'Don’t let me hear the nameagain!”“I won’t indeed!” said Alice, in a great hurry to change the subject ofconversation.',
#      'chapter': 'II',
#      'position': {'start': 56, 'end': 61}},
#     {'sentence': 'The Mouse did notanswer, so Alice went on eagerly: “There is such a nice little dog nearour house I should like to show you!',
#      'chapter': 'II',
#      'position': {'start': 28, 'end': 33}},
#     {'sentence': 'He saysit kills all the rats and—oh dear!” cried Alice in a sorrowful tone,“I’m afraid I’ve offended it again!”',
#      'chapter': 'II',
#      'position': {'start': 49, 'end': 54}},
#     {'sentence': 'When theMouse heard this, it turned round and swam slowly back to her: its facewas quite pale (with passion, Alice thought), and it said in a lowtrembling voice, “Let us get to the shore, and then I’ll tell you myhistory, and you’ll understand why it is I hate cats and dogs.”',
#      'chapter': 'II',
#      'position': {'start': 109, 'end': 114}},
#     {'sentence': 'Aliceled the way, and the whole party swam to the shore.',
#      'chapter': 'II',
#      'position': {'start': 0, 'end': 5}},
#     {'sentence': 'The first question of course was, how to get dry again: they had aconsultation about this, and after a few minutes it seemed quitenatural to Alice to find herself talking familiarly with them, as ifshe had known them all her life.',
#      'chapter': 'III',
#      'position': {'start': 141, 'end': 146}},
#     {'sentence': 'Indeed, she had quite a long argumentwith the Lory, who at last turned sulky, and would only say, “I amolder than you, and must know better;” and this Alice would not allowwithout knowing how old it was, and, as the Lory positively refused totell its age, there was no more to be said.',
#      'chapter': 'III',
#      'position': {'start': 151, 'end': 156}},
#     {'sentence': 'Alice kept her eyes anxiously fixed on it, for shefelt sure she would catch a bad cold if she did not get dry very soon.',
#      'chapter': 'III',
#      'position': {'start': 0, 'end': 5}},
#     {'sentence': 'it continued,turning to Alice as it spoke.',
#      'chapter': 'III',
#      'position': {'start': 24, 'end': 29}},
#     {'sentence': '“As wet as ever,” said Alice in a melancholy tone: “it doesn’t seem todry me at all.”',
#      'chapter': 'III',
#      'position': {'start': 23, 'end': 28}},
#     {'sentence': '“What _is_ a Caucus-race?” said Alice; not that she wanted much toknow, but the Dodo had paused as if it thought that _somebody_ ought tospeak, and no one else seemed inclined to say anything.',
#      'chapter': 'III',
#      'position': {'start': 32, 'end': 37}},
#     {'sentence': '“Why, _she_, of course,” said the Dodo, pointing to Alice with onefinger; and the whole party at once crowded round her, calling out in aconfused way, “Prizes!',
#      'chapter': 'III',
#      'position': {'start': 52, 'end': 57}},
#     {'sentence': 'Alice had no idea what to do, and in despair she put her hand in herpocket, and pulled out a box of comfits, (luckily the salt water hadnot got into it), and handed them round as prizes.',
#      'chapter': 'III',
#      'position': {'start': 0, 'end': 5}},
#     {'sentence': 'he went on, turning to Alice.',
#      'chapter': 'III',
#      'position': {'start': 23, 'end': 28}},
#     {'sentence': '“Only a thimble,” said Alice sadly.',
#      'chapter': 'III',
#      'position': {'start': 23, 'end': 28}},
#     {'sentence': 'Alice thought the whole thing very absurd, but they all looked so gravethat she did not dare to laugh; and, as she could not think of anythingto say, she simply bowed, and took the thimble, looking as solemn asshe could.',
#      'chapter': 'III',
#      'position': {'start': 0, 'end': 5}},
#     {'sentence': '“You promised to tell me your history, you know,” said Alice, “and whyit is you hate—C and D,” she added in a whisper, half afraid that itwould be offended again.',
#      'chapter': 'III',
#      'position': {'start': 55, 'end': 60}},
#     {'sentence': '“Mine is a long and a sad tale!” said the Mouse, turning to Alice, andsighing.',
#      'chapter': 'III',
#      'position': {'start': 60, 'end': 65}},
#     {'sentence': '“It _is_ a long tail, certainly,” said Alice, looking down with wonderat the Mouse’s tail; “but why do you call it sad?”',
#      'chapter': 'III',
#      'position': {'start': 39, 'end': 44}},
#     {'sentence': '”“You are not attending!” said the Mouse to Alice severely.',
#      'chapter': 'III',
#      'position': {'start': 44, 'end': 49}},
#     {'sentence': '“What areyou thinking of?”“I beg your pardon,” said Alice very humbly: “you had got to the fifthbend, I think?”“I had _not!_” cried the Mouse, sharply and very angrily.',
#      'chapter': 'III',
#      'position': {'start': 52, 'end': 57}},
#     {'sentence': '“A knot!” said Alice, always ready to make herself useful, and lookinganxiously about her.',
#      'chapter': 'III',
#      'position': {'start': 15, 'end': 20}},
#     {'sentence': '“You insult me by talking such nonsense!”“I didn’t mean it!” pleaded poor Alice.',
#      'chapter': 'III',
#      'position': {'start': 74, 'end': 79}},
#     {'sentence': 'Alice called after it; andthe others all joined in chorus, “Yes, please do!”',
#      'chapter': 'III',
#      'position': {'start': 0, 'end': 5}},
#     {'sentence': '“You’re enough to try the patience of an oyster!”“I wish I had our Dinah here, I know I do!” said Alice aloud,addressing nobody in particular.',
#      'chapter': 'III',
#      'position': {'start': 98, 'end': 103}},
#     {'sentence': 'Alice replied eagerly, for she was always ready to talk about her pet:“Dinah’s our cat.',
#      'chapter': 'III',
#      'position': {'start': 0, 'end': 5}},
#     {'sentence': 'On various pretexts they all moved off, and Alice was soon leftalone.',
#      'chapter': 'III',
#      'position': {'start': 44, 'end': 49}},
#     {'sentence': 'And here poor Alice began to cry again, for she felt verylonely and low-spirited.',
#      'chapter': 'III',
#      'position': {'start': 14, 'end': 19}},
#     {'sentence': 'Alice guessed in amoment that it was looking for the fan and the pair of white kidgloves, and she very good-naturedly began hunting about for them, butthey were nowhere to be seen—everything seemed to have changed sinceher swim in the pool, and the great hall, with the glass table and thelittle door, had vanished completely.',
#      'chapter': 'IV',
#      'position': {'start': 0, 'end': 5}},
#     {'sentence': 'Very soon the Rabbit noticed Alice, as she went hunting about, andcalled out to her in an angry tone, “Why, Mary Ann, what _are_ youdoing out here?',
#      'chapter': 'IV',
#      'position': {'start': 29, 'end': 34}},
#     {'sentence': 'And Alice was so much frightened that she ran offat once in the direction it pointed to, without trying to explain themistake it had made.',
#      'chapter': 'IV',
#      'position': {'start': 4, 'end': 9}},
#     {'sentence': '“How queer it seems,” Alice said to herself, “to be going messages fora rabbit!',
#      'chapter': 'IV',
#      'position': {'start': 22, 'end': 27}},
#     {'sentence': 'And shebegan fancying the sort of thing that would happen: “‘Miss Alice!',
#      'chapter': 'IV',
#      'position': {'start': 66, 'end': 71}},
#     {'sentence': 'Only Idon’t think,” Alice went on, “that they’d let Dinah stop in the houseif it began ordering people about like that!”',
#      'chapter': 'IV',
#      'position': {'start': 20, 'end': 25}},
#     {'sentence': 'What _will_ become of me?”Luckily for Alice, the little magic bottle had now had its full effect,and she grew no larger: still it was very uncomfortable, and, as thereseemed to be no sort of chance of her ever getting out of the roomagain, no wonder she felt unhappy.',
#      'chapter': 'IV',
#      'position': {'start': 38, 'end': 43}},
#     {'sentence': '“It was much pleasanter at home,” thought poor Alice, “when one wasn’talways growing larger and smaller, and being ordered about by mice andrabbits.',
#      'chapter': 'IV',
#      'position': {'start': 47, 'end': 52}},
#     {'sentence': '“But then,” thought Alice, “shall I _never_ get any older than I amnow?',
#      'chapter': 'IV',
#      'position': {'start': 20, 'end': 25}},
#     {'sentence': 'Oh, I shouldn’t like _that!_”“Oh, you foolish Alice!”',
#      'chapter': 'IV',
#      'position': {'start': 46, 'end': 51}},
#     {'sentence': 'Alice knew it wasthe Rabbit coming to look for her, and she trembled till she shook thehouse, quite forgetting that she was now about a thousand times aslarge as the Rabbit, and had no reason to be afraid of it.',
#      'chapter': 'IV',
#      'position': {'start': 0, 'end': 5}},
#     {'sentence': 'Presently the Rabbit came up to the door, and tried to open it; but, asthe door opened inwards, and Alice’s elbow was pressed hard against it,that attempt proved a failure.',
#      'chapter': 'IV',
#      'position': {'start': 100, 'end': 105}},
#     {'sentence': 'Alice heard it say to itself “Then I’llgo round and get in at the window.”“_That_',
#      'chapter': 'IV',
#      'position': {'start': 0, 'end': 5}},
#     {'sentence': 'you won’t!” thought Alice, and, after waiting till she fanciedshe heard the Rabbit just under the window, she suddenly spread out herhand, and made a snatch in the air.',
#      'chapter': 'IV',
#      'position': {'start': 20, 'end': 25}},
#     {'sentence': '“Sure, it does, yer honour: but it’s an arm for all that.”“Well, it’s got no business there, at any rate: go and take it away!”There was a long silence after this, and Alice could only hear whispersnow and then; such as, “Sure, I don’t like it, yer honour, at all, atall!”',
#      'chapter': 'IV',
#      'position': {'start': 168, 'end': 173}},
#     {'sentence': '“What a numberof cucumber-frames there must be!” thought Alice.',
#      'chapter': 'IV',
#      'position': {'start': 57, 'end': 62}},
#     {'sentence': 'So Bill’s got to come down the chimney, has he?” said Alice toherself.',
#      'chapter': 'IV',
#      'position': {'start': 54, 'end': 59}},
#     {'sentence': 'Last came a little feeble, squeaking voice, (“That’s Bill,” thoughtAlice,) “Well, I hardly know—No more, thank ye; I’m better now—but I’ma deal too flustered to tell you—all I know is, something comes at melike a Jack-in-the-box, and up I goes like a sky-rocket!”',
#      'chapter': 'IV',
#      'position': {'start': 67, 'end': 72}},
#     {'sentence': '“We must burn the house down!” said the Rabbit’s voice; and Alicecalled out as loud as she could, “If you do, I’ll set Dinah at you!”There was a dead silence instantly, and Alice thought to herself, “Iwonder what they _will_ do next!',
#      'chapter': 'IV',
#      'position': {'start': 60, 'end': 65}},
#     {'sentence': 'After a minute or two, they began moving about again, andAlice heard the Rabbit say, “A barrowful will do, to begin with.”“A barrowful of _what?_” thought Alice; but she had not long to doubt,for the next moment a shower of little pebbles came rattling in at thewindow, and some of them hit her in the face.',
#      'chapter': 'IV',
#      'position': {'start': 57, 'end': 62}},
#     {'sentence': 'Alice noticed with some surprise that the pebbles were all turning intolittle cakes as they lay on the floor, and a bright idea came into herhead.',
#      'chapter': 'IV',
#      'position': {'start': 0, 'end': 5}},
#     {'sentence': 'They all made a rush at Alice the moment sheappeared; but she ran off as hard as she could, and soon found herselfsafe in a thick wood.',
#      'chapter': 'IV',
#      'position': {'start': 24, 'end': 29}},
#     {'sentence': '“The first thing I’ve got to do,” said Alice to herself, as shewandered about in the wood, “is to grow to my right size again; and thesecond thing is to find my way into that lovely garden.',
#      'chapter': 'IV',
#      'position': {'start': 39, 'end': 44}},
#     {'sentence': '“Poor littlething!” said Alice, in a coaxing tone, and she tried hard to whistle toit; but she was terribly frightened all the time at the thought that itmight be hungry, in which case it would be very likely to eat her up inspite of all her coaxing.',
#      'chapter': 'IV',
#      'position': {'start': 25, 'end': 30}},
#     {'sentence': 'Hardly knowing what she did, she picked up a little bit of stick, andheld it out to the puppy; whereupon the puppy jumped into the air offall its feet at once, with a yelp of delight, and rushed at the stick,and made believe to worry it; then Alice dodged behind a great thistle,to keep herself from being run over; and the moment she appeared on theother side, the puppy made another rush at the stick, and tumbled headover heels in its hurry to get hold of it; then Alice, thinking it wasvery like having a game of play with a cart-horse, and expecting everymoment to be trampled under its feet, ran round the thistle again; thenthe puppy began a series of short charges at the stick, running a verylittle way forwards each time and a long way back, and barking hoarselyall the while, till at last it sat down a good way off, panting, withits tongue hanging out of its mouth, and its great eyes half shut.',
#      'chapter': 'IV',
#      'position': {'start': 243, 'end': 248}},
#     {'sentence': 'This seemed to Alice a good opportunity for making her escape; so sheset off at once, and ran till she was quite tired and out of breath,and till the puppy’s bark sounded quite faint in the distance.',
#      'chapter': 'IV',
#      'position': {'start': 15, 'end': 20}},
#     {'sentence': '“And yet what a dear little puppy it was!” said Alice, as she leantagainst a buttercup to rest herself, and fanned herself with one of theleaves: “I should have liked teaching it tricks very much, if—if I’donly been the right size to do it!',
#      'chapter': 'IV',
#      'position': {'start': 48, 'end': 53}},
#     {'sentence': 'Alice looked all round her atthe flowers and the blades of grass, but she did not see anything thatlooked like the right thing to eat or drink under the circumstances.',
#      'chapter': 'IV',
#      'position': {'start': 0, 'end': 5}},
#     {'sentence': 'Alice replied,rather shyly, “I—I hardly know, sir, just at present—at least I knowwho I _was_ when I got up this morning, but I think I must have beenchanged several times since then.”“What do you mean by that?” said the Caterpillar sternly.',
#      'chapter': 'V',
#      'position': {'start': 0, 'end': 5}},
#     {'sentence': '“Explainyourself!”“I can’t explain _myself_, I’m afraid, sir,” said Alice, “because I’mnot myself, you see.”',
#      'chapter': 'V',
#      'position': {'start': 68, 'end': 73}},
#     {'sentence': '“I’m afraid I can’t put it more clearly,” Alice replied very politely,“for I can’t understand it myself to begin with; and being so manydifferent sizes in a day is very confusing.”',
#      'chapter': 'V',
#      'position': {'start': 42, 'end': 47}},
#     {'sentence': '“Well, perhaps you haven’t found it so yet,” said Alice; “but when youhave to turn into a chrysalis—you will some day, you know—and thenafter that into a butterfly, I should think you’ll feel it a littlequeer, won’t you?”“Not a bit,” said the Caterpillar.',
# ...
#      'chapter': 'XI',
#      'position': {'start': 32, 'end': 37}},
#     {'sentence': 'Imagine hersurprise, when the White Rabbit read out, at the top of his shrilllittle voice, the name “Alice!”',
#      'chapter': 'XI',
#      'position': {'start': 101, 'end': 106}},
#     {'sentence': 'Alice’s Evidence“Here!” cried Alice, quite forgetting in the flurry of the moment howlarge she had grown in the last few minutes, and she jumped up in sucha hurry that she tipped over the jury-box with the edge of her skirt,upsetting all the jurymen on to the heads of the crowd below, and therethey lay sprawling about, reminding her very much of a globe ofgoldfish she had accidentally upset the week before.',
#      'chapter': 'XII',
#      'position': {'start': 0, 'end': 5}},
#     {'sentence': '“The trial cannot proceed,” said the King in a very grave voice, “untilall the jurymen are back in their proper places—_all_,” he repeatedwith great emphasis, looking hard at Alice as he said so.Alice looked at the jury-box, and saw that, in her haste, she had putthe Lizard in head downwards, and the poor little thing was waving itstail about in a melancholy way, being quite unable to move.',
#      'chapter': 'XII',
#      'position': {'start': 175, 'end': 180}},
#     {'sentence': 'the King said to Alice.',
#      'chapter': 'XII',
#      'position': {'start': 17, 'end': 22}},
#     {'sentence': '“Nothing,” said Alice.',
#      'chapter': 'XII',
#      'position': {'start': 16, 'end': 21}},
#     {'sentence': '“Nothing whatever,” said Alice.',
#      'chapter': 'XII',
#      'position': {'start': 25, 'end': 30}},
#     {'sentence': 'Alice could see this, as she was near enough to look over their slates;“but it doesn’t matter a bit,” she thought to herself.',
#      'chapter': 'XII',
#      'position': {'start': 0, 'end': 5}},
#     {'sentence': 'Everybody looked at Alice.',
#      'chapter': 'XII',
#      'position': {'start': 20, 'end': 25}},
#     {'sentence': '“_I’m_ not a mile high,” said Alice.',
#      'chapter': 'XII',
#      'position': {'start': 30, 'end': 35}},
#     {'sentence': '“Well, I shan’t go, at any rate,” said Alice: “besides, that’s not aregular rule: you invented it just now.”',
#      'chapter': 'XII',
#      'position': {'start': 39, 'end': 44}},
#     {'sentence': '“Then it ought to be Number One,” said Alice.',
#      'chapter': 'XII',
#      'position': {'start': 39, 'end': 44}},
#     {'sentence': '“It proves nothing of the sort!” said Alice.',
#      'chapter': 'XII',
#      'position': {'start': 38, 'end': 43}},
#     {'sentence': 'For this must ever beA secret, kept from all the rest,    Between yourself and me.”“That’s the most important piece of evidence we’ve heard yet,” said theKing, rubbing his hands; “so now let the jury—”“If any one of them can explain it,” said Alice, (she had grown solarge in the last few minutes that she wasn’t a bit afraid ofinterrupting him,) “I’ll give him sixpence.',
#      'chapter': 'XII',
#      'position': {'start': 243, 'end': 248}},
#     {'sentence': '“All right, so far,” said the King, and he went on muttering over theverses to himself: “‘_We know it to be true_—’ that’s the jury, ofcourse—‘_I gave her one, they gave him two_—’ why, that must be what hedid with the tarts, you know—”“But, it goes on ‘_they all returned from him to you_,’” said Alice.',
#      'chapter': 'XII',
#      'position': {'start': 298, 'end': 303}},
#     {'sentence': '“Sentence first—verdict afterwards.”“Stuff and nonsense!” said Alice loudly.',
#      'chapter': 'XII',
#      'position': {'start': 63, 'end': 68}},
#     {'sentence': '“I won’t!” said Alice.',
#      'chapter': 'XII',
#      'position': {'start': 16, 'end': 21}},
#     {'sentence': '“Who cares for you?” said Alice, (she had grown to her full size bythis time.)',
#      'chapter': 'XII',
#      'position': {'start': 26, 'end': 31}},
#     {'sentence': '“Wake up, Alice dear!” said her sister; “Why, what a long sleep you’vehad!”“Oh, I’ve had such a curious dream!” said Alice, and she told hersister, as well as she could remember them, all these strangeAdventures of hers that you have just been reading about; and when shehad finished, her sister kissed her, and said, “It _was_ a curiousdream, dear, certainly: but now run in to your tea; it’s getting late.”',
#      'chapter': 'XII',
#      'position': {'start': 10, 'end': 15}},
#     {'sentence': 'So Alice got up and ran off, thinking while she ran, as well she might,what a wonderful dream it had been.',
#      'chapter': 'XII',
#      'position': {'start': 3, 'end': 8}},
#     {'sentence': 'But her sister sat still just as she left her, leaning her head on herhand, watching the setting sun, and thinking of little Alice and allher wonderful Adventures, till she too began dreaming after a fashion,and this was her dream:—',
#      'chapter': 'XII',
#      'position': {'start': 125, 'end': 130}},
#     {'sentence': 'First, she dreamed of little Alice herself, and once again the tinyhands were clasped upon her knee, and the bright eager eyes werelooking up into hers—she could hear the very tones of her voice, andsee that queer little toss of her head to keep back the wandering hairthat _would_ always get into her eyes—and still as she listened, orseemed to listen, the whole place around her became alive with thestrange creatures of her little sister’s dream.',
#      'chapter': 'XII',
#      'position': {'start': 29, 'end': 34}}]},
#   {'name': 'Bill',
#    'aliases': 'Bill',
#    'frequency': 14,
#    'occurrences': [{'sentence': 'The Rabbit Sends in a Little BillIt was the White Rabbit, trotting slowly back again, and lookinganxiously about as it went, as if it had lost something; and she heardit muttering to itself “The Duchess!',
#      'chapter': 'IV',
#      'position': {'start': 29, 'end': 33}},
#     {'sentence': 'She waited for some time without hearing anything more: at last came arumbling of little cartwheels, and the sound of a good many voices alltalking together: she made out the words: “Where’s the otherladder?—Why, I hadn’t to bring but one; Bill’s got the other—Bill!fetch it here, lad!—Here, put ’em up at this corner—No, tie ’emtogether first—they don’t reach half high enough yet—Oh!',
#      'chapter': 'IV',
#      'position': {'start': 240, 'end': 244}},
#     {'sentence': 'they’ll dowell enough; don’t be particular—Here, Bill!',
#      'chapter': 'IV',
#      'position': {'start': 49, 'end': 53}},
#     {'sentence': '(a loud crash)—“Now, who did that?—It was Bill, Ifancy—Who’s to go down the chimney?—Nay, _I_ shan’t!',
#      'chapter': 'IV',
#      'position': {'start': 42, 'end': 46}},
#     {'sentence': 'I won’t, then!—Bill’s to go down—Here, Bill!',
#      'chapter': 'IV',
#      'position': {'start': 15, 'end': 19}},
#     {'sentence': 'So Bill’s got to come down the chimney, has he?” said Alice toherself.',
#      'chapter': 'IV',
#      'position': {'start': 3, 'end': 7}},
#     {'sentence': '“Shy, they seem to put everything upon Bill!',
#      'chapter': 'IV',
#      'position': {'start': 39, 'end': 43}},
#     {'sentence': 'I wouldn’t be inBill’s place for a good deal: this fireplace is narrow, to be sure; butI _think_',
#      'chapter': 'IV',
#      'position': {'start': 16, 'end': 20}},
#     {'sentence': 'She drew her foot as far down the chimney as she could, and waited tillshe heard a little animal (she couldn’t guess of what sort it was)scratching and scrambling about in the chimney close above her: then,saying to herself “This is Bill,” she gave one sharp kick, and waitedto see what would happen next.',
#      'chapter': 'IV',
#      'position': {'start': 233, 'end': 237}},
#     {'sentence': 'The first thing she heard was a general chorus of “There goes Bill!”then the Rabbit’s voice along—“Catch him, you by the hedge!”',
#      'chapter': 'IV',
#      'position': {'start': 62, 'end': 66}},
#     {'sentence': 'Last came a little feeble, squeaking voice, (“That’s Bill,” thoughtAlice,) “Well, I hardly know—No more, thank ye; I’m better now—but I’ma deal too flustered to tell you—all I know is, something comes at melike a Jack-in-the-box, and up I goes like a sky-rocket!”',
#      'chapter': 'IV',
#      'position': {'start': 53, 'end': 57}},
#     {'sentence': 'The poor little Lizard, Bill,was in the middle, being held up by two guinea-pigs, who were giving itsomething out of a bottle.',
#      'chapter': 'IV',
#      'position': {'start': 24, 'end': 28}},
#     {'sentence': 'She did it so quicklythat the poor little juror (it was Bill, the Lizard) could not make outat all what had become of it; so, after hunting all about for it, hewas obliged to write with one finger for the rest of the day; and thiswas of very little use, as it left no mark on the slate.',
#      'chapter': 'XI',
#      'position': {'start': 56, 'end': 60}},
#     {'sentence': '(The unfortunate little Bill had left off writing on hisslate with one finger, as he found it made no mark; but he now hastilybegan again, using the ink, that was trickling down his face, as longas it lasted.)',
#      'chapter': 'XII',
#      'position': {'start': 24, 'end': 28}}]},
#   {'name': 'Mouse',
#    'aliases': 'Mouse',
#    'frequency': 15,
#    'occurrences': [{'sentence': 'So shebegan: “O Mouse, do you know the way out of this pool?',
#      'chapter': 'II',
#      'position': {'start': 16, 'end': 21}},
#     {'sentence': 'I am very tiredof swimming about here, O Mouse!”',
#      'chapter': 'II',
#      'position': {'start': 41, 'end': 46}},
#     {'sentence': 'The Mouse looked at her ratherinquisitively, and seemed to her to wink with one of its little eyes,but it said nothing.',
#      'chapter': 'II',
#      'position': {'start': 4, 'end': 9}},
#     {'sentence': 'The Mouse gave asudden leap out of the water, and seemed to quiver all over withfright.',
#      'chapter': 'II',
#      'position': {'start': 4, 'end': 9}},
#     {'sentence': '“I quite forgot you didn’t likecats.”“Not like cats!” cried the Mouse, in a shrill, passionate voice.',
#      'chapter': 'II',
#      'position': {'start': 64, 'end': 69}},
#     {'sentence': 'She is such a dearquiet thing,” Alice went on, half to herself, as she swam lazily aboutin the pool, “and she sits purring so nicely by the fire, licking herpaws and washing her face—and she is such a nice soft thing tonurse—and she’s such a capital one for catching mice—oh, I beg yourpardon!” cried Alice again, for this time the Mouse was bristling allover, and she felt certain it must be really offended.',
#      'chapter': 'II',
#      'position': {'start': 332, 'end': 337}},
#     {'sentence': '“We won’t talkabout her any more if you’d rather not.”“We indeed!” cried the Mouse, who was trembling down to the end of histail.',
#      'chapter': 'II',
#      'position': {'start': 77, 'end': 82}},
#     {'sentence': 'The Mouse did notanswer, so Alice went on eagerly: “There is such a nice little dog nearour house I should like to show you!',
#      'chapter': 'II',
#      'position': {'start': 4, 'end': 9}},
#     {'sentence': 'For the Mouse was swimming awayfrom her as hard as it could go, and making quite a commotion in thepool as it went.',
#      'chapter': 'II',
#      'position': {'start': 8, 'end': 13}},
#     {'sentence': 'So she called softly after it, “Mouse dear!',
#      'chapter': 'II',
#      'position': {'start': 32, 'end': 37}},
#     {'sentence': 'When theMouse heard this, it turned round and swam slowly back to her: its facewas quite pale (with passion, Alice thought), and it said in a lowtrembling voice, “Let us get to the shore, and then I’ll tell you myhistory, and you’ll understand why it is I hate cats and dogs.”',
#      'chapter': 'II',
#      'position': {'start': 8, 'end': 13}},
#     {'sentence': 'At last the Mouse, who seemed to be a person of authority among them,called out, “Sit down, all of you, and listen to me!',
#      'chapter': 'III',
#      'position': {'start': 12, 'end': 17}},
#     {'sentence': 'They all sat down at once, in a large ring, with theMouse in the middle.',
#      'chapter': 'III',
#      'position': {'start': 52, 'end': 57}},
#     {'sentence': '“Ahem!” said the Mouse with an important air, “are you all ready?',
#      'chapter': 'III',
#      'position': {'start': 17, 'end': 22}},
#     {'sentence': '“I beg your pardon!” said the Mouse, frowning, but very politely: “Didyou speak?”“Not I!” said the Lory hastily.',
#      'chapter': 'III',
#      'position': {'start': 30, 'end': 35}},
#     {'sentence': '“I thought you did,” said the Mouse.',
#      'chapter': 'III',
#      'position': {'start': 30, 'end': 35}},
#     {'sentence': '“Found _it_,” the Mouse replied rather crossly: “of course you knowwhat ‘it’ means.”“I know what ‘it’ means well enough, when _I_ find a thing,” said theDuck: “it’s generally a frog or a worm.',
#      'chapter': 'III',
#      'position': {'start': 18, 'end': 23}},
#     {'sentence': 'The question is, what did thearchbishop find?”The Mouse did not notice this question, but hurriedly went on, “‘—foundit advisable to go with Edgar Atheling to meet William and offer himthe crown.',
#      'chapter': 'III',
#      'position': {'start': 50, 'end': 55}},
#     {'sentence': '“But she must have a prize herself, you know,” said the Mouse.',
#      'chapter': 'III',
#      'position': {'start': 56, 'end': 61}},
#     {'sentence': 'However, it was over at last, and they sat down again in a ring, andbegged the Mouse to tell them something more.',
#      'chapter': 'III',
#      'position': {'start': 79, 'end': 84}},
#     {'sentence': '“Mine is a long and a sad tale!” said the Mouse, turning to Alice, andsighing.',
#      'chapter': 'III',
#      'position': {'start': 42, 'end': 47}},
#     {'sentence': '“It _is_ a long tail, certainly,” said Alice, looking down with wonderat the Mouse’s tail; “but why do you call it sad?”',
#      'chapter': 'III',
#      'position': {'start': 77, 'end': 82}},
#     {'sentence': 'And she kept onpuzzling about it while the Mouse was speaking, so that her idea of thetale was something like this:—         “Fury said to a mouse, That he met in the house, ‘Let us both         go to law: _',
#      'chapter': 'III',
#      'position': {'start': 43, 'end': 48}},
#     {'sentence': '”“You are not attending!” said the Mouse to Alice severely.',
#      'chapter': 'III',
#      'position': {'start': 35, 'end': 40}},
#     {'sentence': '“What areyou thinking of?”“I beg your pardon,” said Alice very humbly: “you had got to the fifthbend, I think?”“I had _not!_” cried the Mouse, sharply and very angrily.',
#      'chapter': 'III',
#      'position': {'start': 136, 'end': 141}},
#     {'sentence': '“Oh, do let me help to undo it!”“I shall do nothing of the sort,” said the Mouse, getting up andwalking away.',
#      'chapter': 'III',
#      'position': {'start': 75, 'end': 80}},
#     {'sentence': '“But you’re so easily offended,you know!”The Mouse only growled in reply.',
#      'chapter': 'III',
#      'position': {'start': 45, 'end': 50}},
#     {'sentence': 'but the Mouse onlyshook its head impatiently, and walked a little quicker.',
#      'chapter': 'III',
#      'position': {'start': 8, 'end': 13}},
#     {'sentence': 'In a little while, however, she again heard alittle pattering of footsteps in the distance, and she looked upeagerly, half hoping that the Mouse had changed his mind, and wascoming back to finish his story.',
#      'chapter': 'III',
#      'position': {'start': 139, 'end': 144}},
#     {'sentence': 'The long grass rustled at her feet as the White Rabbit hurried by—thefrightened Mouse splashed his way through the neighbouring pool—shecould hear the rattle of the teacups as the March Hare and his friendsshared their never-ending meal, and the shrill voice of the Queenordering off her unfortunate guests to execution—once more the pig-babywas sneezing on the Duchess’s knee, while plates and dishes crashedaround it—once more the shriek of the Gryphon, the squeaking of theLizard’s slate-pencil, and the choking of the suppressed guinea-pigs,filled the air, mixed up with the distant sobs of the miserable MockTurtle.',
#      'chapter': 'XII',
#      'position': {'start': 80, 'end': 85}}]}]}
